# %%
# cross sections at an angle through a fixed center point

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import wrf
import xarray
from netCDF4 import Dataset
from datetime import timedelta, date

import cartopy.crs as crs
from cartopy.feature import NaturalEarthFeature
from cartopy import crs
from cartopy.feature import NaturalEarthFeature, COLORS
from matplotlib.cm import get_cmap

# %%
# colormap definition with white in the middle
n=39
x = 0.5
lower = plt.cm.seismic_r(np.linspace(0, x, n))
white = plt.cm.seismic_r(np.ones(80-2*n)*x)
upper = plt.cm.seismic_r(np.linspace(1-x, 1, n))
colors = np.vstack((lower, white, upper))
from matplotlib.colors import LinearSegmentedColormap
tmap = LinearSegmentedColormap.from_list('map_white', colors)

# %%
########## angled cross section through a fixed center point #########

# ── WRF data location ──────────────────────────────────────────────────────────
baseFolder = '/glade/derecho/scratch/gduine/mountain_fire/1km/'

# Glob all domain-3 output files in chronological order
wrf_files = sorted(glob.glob(os.path.join(baseFolder, 'wrfout_d03_*')))
print(f'Found {len(wrf_files)} WRF files')

# ── Cross-section geometry ──────────────────────────────────────────────────────
center_lat       = 34.318    # center point latitude  (°N)
center_lon       = -118.968  # center point longitude (°W, negative)
angle_from_north = 50.0      # degrees clockwise from north
half_length_km   = 70.0      # half-length of the cross section (km)

# Compute start (SW) and end (NE) lat/lon
angle_rad  = np.radians(angle_from_north)
delta_lat  = half_length_km * np.cos(angle_rad) / 111.0
delta_lon  = half_length_km * np.sin(angle_rad) / (111.0 * np.cos(np.radians(center_lat)))

start_lat = center_lat - delta_lat
start_lon = center_lon - delta_lon
end_lat   = center_lat + delta_lat
end_lon   = center_lon + delta_lon

print(f'Cross section: center ({center_lat}°N, {center_lon}°W), angle {angle_from_north}° from N')
print(f'  SW end: ({start_lat:.4f}°N, {start_lon:.4f}°W)')
print(f'  NE end: ({end_lat:.4f}°N,  {end_lon:.4f}°W)')
print(f'  Along-section wind = U·sin({angle_from_north:.0f}°) + V·cos({angle_from_north:.0f}°)')
print(f'  Positive = toward NE end of section')

# ── Plot / axis settings ────────────────────────────────────────────────────────
g          = 9.81
Vs_levels  = np.arange(-24, 26,  2)   # along-section wind contour levels
W_levels   = np.arange(-5,  5.2, 0.2)
th_levels  = np.arange(260, 340, 1)

xlim1 = -half_length_km   # km from center, SW end
xlim2 =  half_length_km   # km from center, NE end
ylim1 = 0
ylim2 = 3000

# Froude search: only look south of this distance from center (km)
north_limit_km = 15.0

# ── One-time setup (runs on first file) ────────────────────────────────────────
ter        = None
xy         = None
ter_line   = None
dist_1d    = None
cross_start= None
cross_end  = None

# ── Main loop: files then timesteps ────────────────────────────────────────────
for fName in wrf_files:

    ncfile = Dataset(fName)
    print(f'\nOpened: {fName}')

    # First-file initialisation: terrain + cross-section path
    if ter is None:
        ter = wrf.getvar(ncfile, 'ter', -1)

        cross_start = wrf.CoordPair(lat=start_lat, lon=start_lon)
        cross_end   = wrf.CoordPair(lat=end_lat,   lon=end_lon)
        ter_line    = wrf.interpline(ter, wrfin=ncfile,
                                     start_point=cross_start, end_point=cross_end)

        latLocs = [start_lat, end_lat]
        lonLocs = [start_lon, end_lon]
        xy = wrf.ll_to_xy(ncfile, latLocs, lonLocs)

        nx_cross = len(ter_line)
        dist_1d  = np.linspace(xlim1, xlim2, nx_cross)   # km from center
        print(f'Cross-section has {nx_cross} grid points')

    # 6 timesteps per file (every 10 minutes within each hour)
    for idt in range(6):

        print(f'  timestep {idt}')

        # Read 3-D fields
        timeWRF = wrf.getvar(ncfile, 'Times',   idt)
        z       = wrf.getvar(ncfile, 'z',       idt)
        U       = wrf.getvar(ncfile, 'ua',      idt)   # zonal wind (destaggered)
        V       = wrf.getvar(ncfile, 'va',      idt)   # meridional wind (destaggered)
        W       = wrf.getvar(ncfile, 'wa',      idt)
        th      = wrf.getvar(ncfile, 'th',      idt)
        pblh    = wrf.getvar(ncfile, 'PBLH',    idt)
        qv      = wrf.getvar(ncfile, 'QVAPOR',  idt)
        thv     = th * (1.0 + 0.61 * qv)

        # Time string
        ts               = pd.to_datetime(wrf.to_np(timeWRF))
        tsPDT            = ts - pd.DateOffset(hours=7)
        tWRFstr          = ts.strftime('%Y%m%d_%H%M')
        tWRF_strPDT      = tsPDT.strftime('%Y%m%d %H%M')
        tWRF_strPDT_fName= tsPDT.strftime('%Y%m%d_%H%M')

        # Cross-section interpolation along the angled path
        xy_line    = wrf.xy(V,   start_point=xy[:, 0], end_point=xy[:, 1])
        U_cross    = wrf.interp2dxy(U,   xy_line, meta=True)
        V_cross    = wrf.interp2dxy(V,   xy_line, meta=True)
        W_cross    = wrf.interp2dxy(W,   xy_line, meta=True)
        z_cross    = wrf.interp2dxy(z,   xy_line, meta=True)
        th_cross   = wrf.interp2dxy(th,  xy_line, meta=True)
        thv_cross  = wrf.interp2dxy(thv, xy_line, meta=True)
        pblh_cross = wrf.interpline(pblh, wrfin=ncfile,
                                    start_point=cross_start, end_point=cross_end)

        # Rotate wind to along-section component
        # Along-section (positive = toward NE end):  Vs =  U·sin(θ) + V·cos(θ)
        U_np      = wrf.to_np(U_cross)                                    # (nz, nx)
        V_np      = wrf.to_np(V_cross)
        Valong_np = U_np * np.sin(angle_rad) + V_np * np.cos(angle_rad)

        # 2-D distance array for contourf (same shape as V_cross)
        nz, nx = U_np.shape
        dist_2d = np.tile(dist_1d, (nz, 1))

        # Numpy arrays for Froude number calculation (use along-section wind)
        pblh_np = wrf.to_np(pblh_cross)
        thv_np  = wrf.to_np(thv_cross)
        z_np    = wrf.to_np(z_cross)

        if   nz == 54:  offset = 2
        elif nz == 80:  offset = 3
        elif nz == 106: offset = 4
        else:           offset = 2

        fr_profile = np.full(nx, np.nan)

        for ix in range(nx):
            z_col      = z_np[:, ix]
            thv_col    = thv_np[:, ix]
            Valong_col = Valong_np[:, ix]
            zi         = pblh_np[ix]
            if zi <= 0:
                zi = 1.0
            above = np.where(z_col > zi)[0]
            if len(above) == 0:
                continue
            ind_zi   = max(above[0] - 1, 0)
            mean_thv = np.nanmean(thv_col[:ind_zi + 1])
            ind_free = min(ind_zi + offset, nz - 1)
            thv_free = thv_col[ind_free]
            mean_Vs  = np.nanmean(Valong_col[:ind_zi + 1])
            g_prime  = g * (thv_free - mean_thv) / mean_thv
            if g_prime <= 0:
                continue
            fr_profile[ix] = np.abs(mean_Vs) / np.sqrt(g_prime * zi)

        # ── Froude transition detection (in distance space) ─────────────────────
        is_super = fr_profile > 1.0
        transition_dists = {'sub_to_super': None, 'super_to_sub': None}

        for ix in range(nx - 2, -1, -1):   # NE to SW
            if np.isnan(fr_profile[ix]) or np.isnan(fr_profile[ix + 1]):
                continue
            if dist_1d[ix] > north_limit_km:
                continue
            fr_a, fr_b     = fr_profile[ix], fr_profile[ix + 1]
            dist_a, dist_b = dist_1d[ix],    dist_1d[ix + 1]
            dist_cross = dist_a + (1.0 - fr_a) * (dist_b - dist_a) / (fr_b - fr_a)

            if is_super[ix] and not is_super[ix + 1]:
                if transition_dists['sub_to_super'] is None:
                    transition_dists['sub_to_super'] = dist_cross
            elif not is_super[ix] and is_super[ix + 1]:
                if transition_dists['sub_to_super'] is not None \
                        and transition_dists['super_to_sub'] is None:
                    transition_dists['super_to_sub'] = dist_cross

        # ── Plotting ────────────────────────────────────────────────────────────
        fig = plt.figure(figsize=(22, 7))
        xlabel_str = f'Distance along {angle_from_north:.0f}° cross section [km]'
        time_label = 'WRF 1 km ' + tWRF_strPDT[:8] + ' ' + tWRF_strPDT[9:13] + ' PDT'

        # ── Left panel: along-section wind ─────────────────────────────────────
        ax_V = plt.subplot(1, 2, 1)
        Vs_contours = ax_V.contourf(dist_2d, wrf.to_np(z_cross), Valong_np,
                                    levels=Vs_levels, cmap=tmap, extend='both')
        th_contours = ax_V.contour(dist_2d, wrf.to_np(z_cross), wrf.to_np(th_cross),
                                   levels=th_levels, colors='k')
        ax_V.fill_between(dist_1d, np.zeros(nx_cross), wrf.to_np(ter_line),
                          facecolor='saddlebrown')
        plt.clabel(th_contours, inline=1, fontsize=20, levels=th_levels[::3], fmt='%1.0f')
        cbar_V = fig.colorbar(Vs_contours, ax=ax_V, extend='both',
                              orientation='horizontal', location='bottom',
                              shrink=0.7, pad=0.15, aspect=30)
        cbar_V.set_label('Along-section wind [m s$^{-1}$]', fontsize=16)
        cbar_V.ax.tick_params(labelsize=14)
        ax_V.scatter([0], [50], marker='^', color='yellow', edgecolor='black',
                     linewidth=2.0, s=500, zorder=8)
        ax_V.set_ylabel('Elevation [m]', fontsize=24)
        ax_V.set_xlabel(xlabel_str, fontsize=20)
        ax_V.set_title(f'Along-section wind (U·sin{angle_from_north:.0f}°+V·cos{angle_from_north:.0f}°) [m s$^{{-1}}$]',
                       fontsize=18)
        plt.xticks(fontsize=20)
        plt.yticks(fontsize=20)
        plt.text(xlim1 + 1, ylim2 - 200, time_label,
                 fontsize=20,
                 bbox=dict(facecolor='white', edgecolor='white', boxstyle='round,pad=0.3'),
                 zorder=10)
        if transition_dists['sub_to_super'] is not None:
            ax_V.axvline(x=transition_dists['sub_to_super'], color='cyan', linewidth=3.5,
                         linestyle='--', label='sub to super', zorder=9)
        if transition_dists['super_to_sub'] is not None:
            ax_V.axvline(x=transition_dists['super_to_sub'], color='orange', linewidth=3.5,
                         linestyle='--', label='super to sub', zorder=9)
        if any(transition_dists.values()):
            ax_V.legend(fontsize=16, loc='upper right')
        plt.ylim(ylim1, ylim2)
        plt.xlim(xlim1, xlim2)

        # ── Right panel: W-component ────────────────────────────────────────────
        ax_W = plt.subplot(1, 2, 2)
        W_contours = ax_W.contourf(dist_2d, wrf.to_np(z_cross), wrf.to_np(W_cross),
                                   levels=W_levels, cmap=tmap, extend='both')
        th_contours = ax_W.contour(dist_2d, wrf.to_np(z_cross), wrf.to_np(th_cross),
                                   levels=th_levels, colors='k')
        ax_W.fill_between(dist_1d, np.zeros(nx_cross), wrf.to_np(ter_line),
                          facecolor='saddlebrown')
        plt.clabel(th_contours, inline=1, fontsize=20, levels=th_levels[::3], fmt='%1.0f')
        cbar_W = fig.colorbar(W_contours, ax=ax_W, extend='both',
                              orientation='horizontal', location='bottom',
                              shrink=0.7, pad=0.15, aspect=30)
        cbar_W.set_label('W [m s$^{-1}$]', fontsize=16)
        cbar_W.ax.tick_params(labelsize=14)
        ax_W.scatter([0], [50], marker='^', color='yellow', edgecolor='black',
                     linewidth=2.0, s=500, zorder=8)
        ax_W.set_xlabel(xlabel_str, fontsize=20)
        ax_W.set_title('W-component [m s$^{-1}$]', fontsize=18)
        ax_W.set_yticklabels([])
        plt.xticks(fontsize=20)
        plt.text(xlim1 + 1, ylim2 - 200, time_label,
                 fontsize=20,
                 bbox=dict(facecolor='white', edgecolor='white', boxstyle='round,pad=0.3'),
                 zorder=10)
        if transition_dists['sub_to_super'] is not None:
            ax_W.axvline(x=transition_dists['sub_to_super'], color='cyan', linewidth=3.5,
                         linestyle='--', label='sub to super', zorder=9)
        if transition_dists['super_to_sub'] is not None:
            ax_W.axvline(x=transition_dists['super_to_sub'], color='orange', linewidth=3.5,
                         linestyle='--', label='super to sub', zorder=9)
        if any(transition_dists.values()):
            ax_W.legend(fontsize=16, loc='upper right')
        plt.ylim(ylim1, ylim2)
        plt.xlim(xlim1, xlim2)

        # ── Diagnostics ─────────────────────────────────────────────────────────
        print(f'Time: {tWRF_strPDT}')
        print(f'Fr range: {np.nanmin(fr_profile):.3f} – {np.nanmax(fr_profile):.3f}')
        print(f'Supercritical points: {np.sum(is_super)} / {nx}')
        if transition_dists['sub_to_super'] is not None:
            print(f'Sub to Super transition: {transition_dists["sub_to_super"]:+.2f} km from center')
        else:
            print('Sub to Super transition: not found')
        if transition_dists['super_to_sub'] is not None:
            print(f'Super to Sub transition: {transition_dists["super_to_sub"]:+.2f} km from center')
        else:
            print('Super to Sub transition: not found')

        plt.subplots_adjust(wspace=0.15)

        save_fName = (f'MtnFire_wrf1km_Cross_ang{angle_from_north:.0f}N'
                      f'_Valong_Wcomp_theta_{tWRF_strPDT_fName}_PDT.jpg')
        fig.savefig(save_fName, bbox_inches='tight', dpi=100)
        fig.clf()
        plt.close()

        del U_cross, V_cross, W_cross, th_cross, pblh_cross, thv_cross
        del Vs_contours, W_contours, th_contours, cbar_V, cbar_W, ax_V, ax_W, fig
        del tWRFstr, tWRF_strPDT_fName

    ncfile.close()
# Out:
# Found 79 WRF files
# Cross section: center (34.318°N, -118.968°W), angle 50.0° from N
#   SW end: (33.9126°N, -119.5529°W)
#   NE end: (34.7234°N,  -118.3831°W)
#   Along-section wind = U·sin(50°) + V·cos(50°)
#   Positive = toward NE end of section
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_18:00:00
# Cross-section has 148 grid points
#   timestep 0
# Time: 20241105 1100
# Fr range: 2.467 – 66.669
# Supercritical points: 129 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241105 1110
# Fr range: 0.183 – 2.296
# Supercritical points: 8 / 148
# Sub to Super transition: +9.17 km from center
# Super to Sub transition: -12.12 km from center
#   timestep 2
# Time: 20241105 1120
# Fr range: 0.238 – 1.036
# Supercritical points: 2 / 148
# Sub to Super transition: +9.11 km from center
# Super to Sub transition: -4.29 km from center
#   timestep 3
# Time: 20241105 1130
# Fr range: 0.307 – 15.245
# Supercritical points: 11 / 148
# Sub to Super transition: +8.06 km from center
# Super to Sub transition: -7.53 km from center
#   timestep 4
# Time: 20241105 1140
# Fr range: 0.368 – 3.265
# Supercritical points: 10 / 148
# Sub to Super transition: +8.60 km from center
# Super to Sub transition: +6.84 km from center
#   timestep 5
# Time: 20241105 1150
# Fr range: 0.478 – 10.068
# Supercritical points: 20 / 148
# Sub to Super transition: +10.14 km from center
# Super to Sub transition: +9.64 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_19:00:00
#   timestep 0
# Time: 20241105 1200
# Fr range: 0.219 – 4.163
# Supercritical points: 31 / 148
# Sub to Super transition: +10.36 km from center
# Super to Sub transition: +9.13 km from center
#   timestep 1
# Time: 20241105 1210
# Fr range: 0.375 – 1.943
# Supercritical points: 47 / 148
# Sub to Super transition: +10.47 km from center
# Super to Sub transition: +8.25 km from center
#   timestep 2
# Time: 20241105 1220
# Fr range: 0.107 – 5.064
# Supercritical points: 47 / 148
# Sub to Super transition: +9.59 km from center
# Super to Sub transition: +6.36 km from center
#   timestep 3
# Time: 20241105 1230
# Fr range: 0.017 – 6.646
# Supercritical points: 49 / 148
# Sub to Super transition: +9.74 km from center
# Super to Sub transition: -5.03 km from center
#   timestep 4
# Time: 20241105 1240
# Fr range: 0.269 – 3.649
# Supercritical points: 52 / 148
# Sub to Super transition: +9.65 km from center
# Super to Sub transition: -5.08 km from center
#   timestep 5
# Time: 20241105 1250
# Fr range: 0.489 – 6.920
# Supercritical points: 54 / 148
# Sub to Super transition: +8.67 km from center
# Super to Sub transition: -4.24 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_20:00:00
#   timestep 0
# Time: 20241105 1300
# Fr range: 0.071 – 2.948
# Supercritical points: 51 / 148
# Sub to Super transition: +8.71 km from center
# Super to Sub transition: -51.04 km from center
#   timestep 1
# Time: 20241105 1310
# Fr range: 0.509 – 3.432
# Supercritical points: 52 / 148
# Sub to Super transition: +8.57 km from center
# Super to Sub transition: -51.03 km from center
#   timestep 2
# Time: 20241105 1320
# Fr range: 0.505 – 4.595
# Supercritical points: 62 / 148
# Sub to Super transition: +9.61 km from center
# Super to Sub transition: -51.04 km from center
#   timestep 3
# Time: 20241105 1330
# Fr range: 0.506 – 4.915
# Supercritical points: 61 / 148
# Sub to Super transition: +9.54 km from center
# Super to Sub transition: +6.20 km from center
#   timestep 4
# Time: 20241105 1340
# Fr range: 0.470 – 4.340
# Supercritical points: 59 / 148
# Sub to Super transition: +9.62 km from center
# Super to Sub transition: +6.99 km from center
#   timestep 5
# Time: 20241105 1350
# Fr range: 0.450 – 11.690
# Supercritical points: 61 / 148
# Sub to Super transition: +9.41 km from center
# Super to Sub transition: +7.14 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_21:00:00
#   timestep 0
# Time: 20241105 1400
# Fr range: 0.435 – 5.315
# Supercritical points: 57 / 148
# Sub to Super transition: +9.30 km from center
# Super to Sub transition: -5.98 km from center
#   timestep 1
# Time: 20241105 1410
# Fr range: 0.393 – 6.599
# Supercritical points: 57 / 148
# Sub to Super transition: +10.38 km from center
# Super to Sub transition: +8.83 km from center
#   timestep 2
# Time: 20241105 1420
# Fr range: 0.351 – 7.125
# Supercritical points: 54 / 148
# Sub to Super transition: +10.28 km from center
# Super to Sub transition: +9.10 km from center
#   timestep 3
# Time: 20241105 1430
# Fr range: 0.334 – 4.314
# Supercritical points: 54 / 148
# Sub to Super transition: +10.33 km from center
# Super to Sub transition: +9.09 km from center
#   timestep 4
# Time: 20241105 1440
# Fr range: 0.333 – 3.470
# Supercritical points: 48 / 148
# Sub to Super transition: +10.45 km from center
# Super to Sub transition: +8.64 km from center
#   timestep 5
# Time: 20241105 1450
# Fr range: 0.251 – 22.727
# Supercritical points: 42 / 148
# Sub to Super transition: +10.40 km from center
# Super to Sub transition: +9.08 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_22:00:00
#   timestep 0
# Time: 20241105 1500
# Fr range: 0.136 – 8.536
# Supercritical points: 42 / 148
# Sub to Super transition: +10.35 km from center
# Super to Sub transition: +9.22 km from center
#   timestep 1
# Time: 20241105 1510
# Fr range: 0.177 – 7.187
# Supercritical points: 41 / 148
# Sub to Super transition: +13.62 km from center
# Super to Sub transition: +12.38 km from center
#   timestep 2
# Time: 20241105 1520
# Fr range: 0.142 – 6.588
# Supercritical points: 37 / 148
# Sub to Super transition: +10.25 km from center
# Super to Sub transition: +9.46 km from center
#   timestep 3
# Time: 20241105 1530
# Fr range: 0.146 – 6.041
# Supercritical points: 31 / 148
# Sub to Super transition: +10.32 km from center
# Super to Sub transition: +9.39 km from center
#   timestep 4
# Time: 20241105 1540
# Fr range: 0.167 – 8.469
# Supercritical points: 30 / 148
# Sub to Super transition: +12.71 km from center
# Super to Sub transition: +11.56 km from center
#   timestep 5
# Time: 20241105 1550
# Fr range: 0.189 – 9.057
# Supercritical points: 29 / 148
# Sub to Super transition: +12.47 km from center
# Super to Sub transition: +11.68 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_23:00:00
#   timestep 0
# Time: 20241105 1600
# Fr range: 0.086 – 5.869
# Supercritical points: 29 / 148
# Sub to Super transition: +11.83 km from center
# Super to Sub transition: +10.38 km from center
#   timestep 1
# Time: 20241105 1610
# Fr range: 0.038 – 4.655
# Supercritical points: 27 / 148
# Sub to Super transition: -29.84 km from center
# Super to Sub transition: -37.28 km from center
#   timestep 2
# Time: 20241105 1620
# Fr range: 0.005 – 8.796
# Supercritical points: 25 / 148
# Sub to Super transition: -31.84 km from center
# Super to Sub transition: -33.93 km from center
#   timestep 3
# Time: 20241105 1630
# Fr range: 0.019 – 9.414
# Supercritical points: 25 / 148
# Sub to Super transition: +9.86 km from center
# Super to Sub transition: -2.34 km from center
#   timestep 4
# Time: 20241105 1640
# Fr range: 0.015 – 15.970
# Supercritical points: 27 / 148
# Sub to Super transition: +9.66 km from center
# Super to Sub transition: -3.17 km from center
#   timestep 5
# Time: 20241105 1650
# Fr range: 0.002 – 7.010
# Supercritical points: 42 / 148
# Sub to Super transition: +9.47 km from center
# Super to Sub transition: -2.30 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_00:00:00
#   timestep 0
# Time: 20241105 1700
# Fr range: 0.003 – 9.637
# Supercritical points: 54 / 148
# Sub to Super transition: +12.18 km from center
# Super to Sub transition: +11.84 km from center
#   timestep 1
# Time: 20241105 1710
# Fr range: 0.075 – 6.200
# Supercritical points: 57 / 148
# Sub to Super transition: +9.86 km from center
# Super to Sub transition: -6.86 km from center
#   timestep 2
# Time: 20241105 1720
# Fr range: 0.030 – 7.576
# Supercritical points: 57 / 148
# Sub to Super transition: +9.66 km from center
# Super to Sub transition: +6.93 km from center
#   timestep 3
# Time: 20241105 1730
# Fr range: 0.003 – 20.471
# Supercritical points: 52 / 148
# Sub to Super transition: +9.39 km from center
# Super to Sub transition: -7.28 km from center
#   timestep 4
# Time: 20241105 1740
# Fr range: 0.001 – 4.079
# Supercritical points: 50 / 148
# Sub to Super transition: +10.06 km from center
# Super to Sub transition: +6.30 km from center
#   timestep 5
# Time: 20241105 1750
# Fr range: 0.003 – 5.698
# Supercritical points: 45 / 148
# Sub to Super transition: +9.29 km from center
# Super to Sub transition: +5.26 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_01:00:00
#   timestep 0
# Time: 20241105 1800
# Fr range: 0.000 – 8.848
# Supercritical points: 28 / 148
# Sub to Super transition: +8.71 km from center
# Super to Sub transition: +5.85 km from center
#   timestep 1
# Time: 20241105 1810
# Fr range: 0.008 – 4.421
# Supercritical points: 22 / 148
# Sub to Super transition: +8.48 km from center
# Super to Sub transition: +7.68 km from center
#   timestep 2
# Time: 20241105 1820
# Fr range: 0.002 – 2.769
# Supercritical points: 23 / 148
# Sub to Super transition: -69.96 km from center
# Super to Sub transition: not found
#   timestep 3
# Time: 20241105 1830
# Fr range: 0.006 – 2.714
# Supercritical points: 24 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241105 1840
# Fr range: 0.002 – 2.703
# Supercritical points: 22 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241105 1850
# Fr range: 0.000 – 2.717
# Supercritical points: 19 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_02:00:00
#   timestep 0
# Time: 20241105 1900
# Fr range: 0.002 – 2.782
# Supercritical points: 17 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241105 1910
# Fr range: 0.000 – 2.809
# Supercritical points: 15 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241105 1920
# Fr range: 0.002 – 2.801
# Supercritical points: 16 / 148
# Sub to Super transition: -59.19 km from center
# Super to Sub transition: -59.88 km from center
#   timestep 3
# Time: 20241105 1930
# Fr range: 0.013 – 2.783
# Supercritical points: 17 / 148
# Sub to Super transition: -60.64 km from center
# Super to Sub transition: -62.23 km from center
#   timestep 4
# Time: 20241105 1940
# Fr range: 0.006 – 2.753
# Supercritical points: 23 / 148
# Sub to Super transition: -57.72 km from center
# Super to Sub transition: -66.63 km from center
#   timestep 5
# Time: 20241105 1950
# Fr range: 0.004 – 3.187
# Supercritical points: 24 / 148
# Sub to Super transition: -58.58 km from center
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_03:00:00
#   timestep 0
# Time: 20241105 2000
# Fr range: 0.005 – 2.922
# Supercritical points: 22 / 148
# Sub to Super transition: -61.42 km from center
# Super to Sub transition: not found
#   timestep 1
# Time: 20241105 2010
# Fr range: 0.006 – 3.126
# Supercritical points: 21 / 148
# Sub to Super transition: -63.49 km from center
# Super to Sub transition: not found
#   timestep 2
# Time: 20241105 2020
# Fr range: 0.003 – 3.226
# Supercritical points: 20 / 148
# Sub to Super transition: -64.67 km from center
# Super to Sub transition: not found
#   timestep 3
# Time: 20241105 2030
# Fr range: 0.002 – 3.263
# Supercritical points: 25 / 148
# Sub to Super transition: -3.34 km from center
# Super to Sub transition: -6.13 km from center
#   timestep 4
# Time: 20241105 2040
# Fr range: 0.000 – 3.296
# Supercritical points: 30 / 148
# Sub to Super transition: -3.89 km from center
# Super to Sub transition: -10.28 km from center
#   timestep 5
# Time: 20241105 2050
# Fr range: 0.006 – 3.373
# Supercritical points: 30 / 148
# Sub to Super transition: -5.61 km from center
# Super to Sub transition: -9.88 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_04:00:00
#   timestep 0
# Time: 20241105 2100
# Fr range: 0.003 – 3.440
# Supercritical points: 29 / 148
# Sub to Super transition: -8.69 km from center
# Super to Sub transition: -9.75 km from center
#   timestep 1
# Time: 20241105 2110
# Fr range: 0.013 – 3.524
# Supercritical points: 32 / 148
# Sub to Super transition: -60.35 km from center
# Super to Sub transition: not found
#   timestep 2
# Time: 20241105 2120
# Fr range: 0.009 – 6.313
# Supercritical points: 30 / 148
# Sub to Super transition: -59.85 km from center
# Super to Sub transition: -69.20 km from center
#   timestep 3
# Time: 20241105 2130
# Fr range: 0.003 – 3.705
# Supercritical points: 29 / 148
# Sub to Super transition: +14.51 km from center
# Super to Sub transition: +12.92 km from center
#   timestep 4
# Time: 20241105 2140
# Fr range: 0.006 – 3.989
# Supercritical points: 35 / 148
# Sub to Super transition: +14.67 km from center
# Super to Sub transition: +11.49 km from center
#   timestep 5
# Time: 20241105 2150
# Fr range: 0.003 – 4.103
# Supercritical points: 34 / 148
# Sub to Super transition: +14.67 km from center
# Super to Sub transition: +11.40 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_05:00:00
#   timestep 0
# Time: 20241105 2200
# Fr range: 0.000 – 3.883
# Supercritical points: 32 / 148
# Sub to Super transition: +14.54 km from center
# Super to Sub transition: +11.75 km from center
#   timestep 1
# Time: 20241105 2210
# Fr range: 0.002 – 3.587
# Supercritical points: 32 / 148
# Sub to Super transition: +14.61 km from center
# Super to Sub transition: +12.21 km from center
#   timestep 2
# Time: 20241105 2220
# Fr range: 0.001 – 3.473
# Supercritical points: 33 / 148
# Sub to Super transition: +14.68 km from center
# Super to Sub transition: +12.20 km from center
#   timestep 3
# Time: 20241105 2230
# Fr range: 0.003 – 3.426
# Supercritical points: 33 / 148
# Sub to Super transition: +13.89 km from center
# Super to Sub transition: +13.59 km from center
#   timestep 4
# Time: 20241105 2240
# Fr range: 0.004 – 3.356
# Supercritical points: 36 / 148
# Sub to Super transition: -60.09 km from center
# Super to Sub transition: -64.29 km from center
#   timestep 5
# Time: 20241105 2250
# Fr range: 0.000 – 3.197
# Supercritical points: 37 / 148
# Sub to Super transition: -60.91 km from center
# Super to Sub transition: -64.66 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_06:00:00
#   timestep 0
# Time: 20241105 2300
# Fr range: 0.000 – 2.986
# Supercritical points: 32 / 148
# Sub to Super transition: -61.65 km from center
# Super to Sub transition: -65.32 km from center
#   timestep 1
# Time: 20241105 2310
# Fr range: 0.011 – 2.865
# Supercritical points: 25 / 148
# Sub to Super transition: -62.31 km from center
# Super to Sub transition: -64.42 km from center
#   timestep 2
# Time: 20241105 2320
# Fr range: 0.007 – 2.676
# Supercritical points: 24 / 148
# Sub to Super transition: -60.24 km from center
# Super to Sub transition: -61.62 km from center
#   timestep 3
# Time: 20241105 2330
# Fr range: 0.001 – 2.392
# Supercritical points: 19 / 148
# Sub to Super transition: -60.88 km from center
# Super to Sub transition: -62.35 km from center
#   timestep 4
# Time: 20241105 2340
# Fr range: 0.000 – 2.273
# Supercritical points: 17 / 148
# Sub to Super transition: -61.38 km from center
# Super to Sub transition: -64.95 km from center
#   timestep 5
# Time: 20241105 2350
# Fr range: 0.005 – 2.243
# Supercritical points: 14 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_07:00:00
#   timestep 0
# Time: 20241106 0000
# Fr range: 0.005 – 2.274
# Supercritical points: 9 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 0010
# Fr range: 0.000 – 2.287
# Supercritical points: 12 / 148
# Sub to Super transition: -64.46 km from center
# Super to Sub transition: -68.09 km from center
#   timestep 2
# Time: 20241106 0020
# Fr range: 0.002 – 2.231
# Supercritical points: 15 / 148
# Sub to Super transition: -65.31 km from center
# Super to Sub transition: -68.90 km from center
#   timestep 3
# Time: 20241106 0030
# Fr range: 0.003 – 2.061
# Supercritical points: 9 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 0040
# Fr range: 0.002 – 3.186
# Supercritical points: 12 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 0050
# Fr range: 0.001 – 3.197
# Supercritical points: 17 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_08:00:00
#   timestep 0
# Time: 20241106 0100
# Fr range: 0.012 – 2.234
# Supercritical points: 13 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 0110
# Fr range: 0.000 – 1.609
# Supercritical points: 12 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 0120
# Fr range: 0.002 – 1.424
# Supercritical points: 9 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 0130
# Fr range: 0.007 – 1.682
# Supercritical points: 10 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 0140
# Fr range: 0.007 – 2.258
# Supercritical points: 11 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 0150
# Fr range: 0.066 – 2.435
# Supercritical points: 22 / 148
# Sub to Super transition: -3.97 km from center
# Super to Sub transition: -8.96 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_09:00:00
#   timestep 0
# Time: 20241106 0200
# Fr range: 0.001 – 2.634
# Supercritical points: 40 / 148
# Sub to Super transition: +0.19 km from center
# Super to Sub transition: -1.05 km from center
#   timestep 1
# Time: 20241106 0210
# Fr range: 0.016 – 2.672
# Supercritical points: 51 / 148
# Sub to Super transition: +15.56 km from center
# Super to Sub transition: +13.31 km from center
#   timestep 2
# Time: 20241106 0220
# Fr range: 0.002 – 2.545
# Supercritical points: 60 / 148
# Sub to Super transition: +9.50 km from center
# Super to Sub transition: +5.98 km from center
#   timestep 3
# Time: 20241106 0230
# Fr range: 0.025 – 2.771
# Supercritical points: 73 / 148
# Sub to Super transition: +9.23 km from center
# Super to Sub transition: +5.03 km from center
#   timestep 4
# Time: 20241106 0240
# Fr range: 0.014 – 2.355
# Supercritical points: 79 / 148
# Sub to Super transition: +3.15 km from center
# Super to Sub transition: -15.76 km from center
#   timestep 5
# Time: 20241106 0250
# Fr range: 0.019 – 2.767
# Supercritical points: 80 / 148
# Sub to Super transition: +10.01 km from center
# Super to Sub transition: +5.57 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_10:00:00
#   timestep 0
# Time: 20241106 0300
# Fr range: 0.003 – 8.050
# Supercritical points: 90 / 148
# Sub to Super transition: +10.70 km from center
# Super to Sub transition: +5.60 km from center
#   timestep 1
# Time: 20241106 0310
# Fr range: 0.022 – 6.087
# Supercritical points: 91 / 148
# Sub to Super transition: +9.87 km from center
# Super to Sub transition: +5.89 km from center
#   timestep 2
# Time: 20241106 0320
# Fr range: 0.034 – 5.674
# Supercritical points: 93 / 148
# Sub to Super transition: +9.11 km from center
# Super to Sub transition: +5.29 km from center
#   timestep 3
# Time: 20241106 0330
# Fr range: 0.098 – 6.719
# Supercritical points: 91 / 148
# Sub to Super transition: +15.19 km from center
# Super to Sub transition: +4.40 km from center
#   timestep 4
# Time: 20241106 0340
# Fr range: 0.055 – 7.963
# Supercritical points: 90 / 148
# Sub to Super transition: +0.50 km from center
# Super to Sub transition: +0.34 km from center
#   timestep 5
# Time: 20241106 0350
# Fr range: 0.023 – 8.650
# Supercritical points: 88 / 148
# Sub to Super transition: -1.95 km from center
# Super to Sub transition: -8.87 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_11:00:00
#   timestep 0
# Time: 20241106 0400
# Fr range: 0.044 – 8.704
# Supercritical points: 90 / 148
# Sub to Super transition: -2.73 km from center
# Super to Sub transition: -6.28 km from center
#   timestep 1
# Time: 20241106 0410
# Fr range: 0.151 – 10.752
# Supercritical points: 81 / 148
# Sub to Super transition: -1.94 km from center
# Super to Sub transition: -9.00 km from center
#   timestep 2
# Time: 20241106 0420
# Fr range: 0.042 – 8.328
# Supercritical points: 71 / 148
# Sub to Super transition: -3.02 km from center
# Super to Sub transition: -9.25 km from center
#   timestep 3
# Time: 20241106 0430
# Fr range: 0.032 – 11.636
# Supercritical points: 72 / 148
# Sub to Super transition: -13.15 km from center
# Super to Sub transition: -15.14 km from center
#   timestep 4
# Time: 20241106 0440
# Fr range: 0.036 – 8.550
# Supercritical points: 63 / 148
# Sub to Super transition: -18.18 km from center
# Super to Sub transition: -19.11 km from center
#   timestep 5
# Time: 20241106 0450
# Fr range: 0.027 – 24.653
# Supercritical points: 63 / 148
# Sub to Super transition: -68.35 km from center
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_12:00:00
#   timestep 0
# Time: 20241106 0500
# Fr range: 0.009 – 11.353
# Supercritical points: 67 / 148
# Sub to Super transition: -19.49 km from center
# Super to Sub transition: -20.88 km from center
#   timestep 1
# Time: 20241106 0510
# Fr range: 0.001 – 21.053
# Supercritical points: 73 / 148
# Sub to Super transition: -24.03 km from center
# Super to Sub transition: -24.34 km from center
#   timestep 2
# Time: 20241106 0520
# Fr range: 0.007 – 19.333
# Supercritical points: 76 / 148
# Sub to Super transition: -27.03 km from center
# Super to Sub transition: -27.26 km from center
#   timestep 3
# Time: 20241106 0530
# Fr range: 0.008 – 15.341
# Supercritical points: 94 / 148
# Sub to Super transition: -34.16 km from center
# Super to Sub transition: -35.75 km from center
#   timestep 4
# Time: 20241106 0540
# Fr range: 0.000 – 39.015
# Supercritical points: 102 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 0550
# Fr range: 0.010 – 31.455
# Supercritical points: 117 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_13:00:00
#   timestep 0
# Time: 20241106 0600
# Fr range: 0.363 – 12.296
# Supercritical points: 127 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 0610
# Fr range: 0.639 – 14.454
# Supercritical points: 134 / 148
# Sub to Super transition: -69.79 km from center
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 0620
# Fr range: 0.234 – 12.651
# Supercritical points: 140 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 0630
# Fr range: 0.218 – 22.831
# Supercritical points: 141 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 0640
# Fr range: 0.105 – 106.809
# Supercritical points: 141 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 0650
# Fr range: 0.146 – 12.633
# Supercritical points: 141 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_14:00:00
#   timestep 0
# Time: 20241106 0700
# Fr range: 0.496 – 20.552
# Supercritical points: 141 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 0710
# Fr range: 0.369 – 11.568
# Supercritical points: 142 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 0720
# Fr range: 0.214 – 16.356
# Supercritical points: 143 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 0730
# Fr range: 0.602 – 11.646
# Supercritical points: 143 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 0740
# Fr range: 1.088 – 16.711
# Supercritical points: 146 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 0750
# Fr range: 1.180 – 45.349
# Supercritical points: 146 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_15:00:00
#   timestep 0
# Time: 20241106 0800
# Fr range: 1.243 – 46.078
# Supercritical points: 146 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 0810
# Fr range: 1.392 – 62.955
# Supercritical points: 144 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 0820
# Fr range: 1.518 – 56.633
# Supercritical points: 135 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 0830
# Fr range: 1.596 – 47.650
# Supercritical points: 125 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 0840
# Fr range: 2.088 – 79.505
# Supercritical points: 105 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 0850
# Fr range: 2.196 – 71.869
# Supercritical points: 98 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_16:00:00
#   timestep 0
# Time: 20241106 0900
# Fr range: 1.795 – 85.221
# Supercritical points: 95 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 0910
# Fr range: 2.054 – 69.423
# Supercritical points: 92 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 0920
# Fr range: 2.103 – 22.760
# Supercritical points: 90 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 0930
# Fr range: 2.449 – 22.378
# Supercritical points: 89 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 0940
# Fr range: 2.470 – 20.975
# Supercritical points: 90 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 0950
# Fr range: 2.513 – 21.169
# Supercritical points: 92 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_17:00:00
#   timestep 0
# Time: 20241106 1000
# Fr range: 2.580 – 68.439
# Supercritical points: 93 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 1010
# Fr range: 2.646 – 15.689
# Supercritical points: 91 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 1020
# Fr range: 2.080 – 8.584
# Supercritical points: 91 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 1030
# Fr range: 2.121 – 8.526
# Supercritical points: 90 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 1040
# Fr range: 2.651 – 8.323
# Supercritical points: 89 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 1050
# Fr range: 2.607 – 16.169
# Supercritical points: 89 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_18:00:00
#   timestep 0
# Time: 20241106 1100
# Fr range: 2.603 – 19.656
# Supercritical points: 89 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 1110
# Fr range: 2.633 – 10.056
# Supercritical points: 89 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 1120
# Fr range: 2.675 – 9.735
# Supercritical points: 92 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 1130
# Fr range: 2.182 – 9.440
# Supercritical points: 94 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 1140
# Fr range: 2.195 – 12.451
# Supercritical points: 91 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 1150
# Fr range: 2.217 – 32.931
# Supercritical points: 92 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_19:00:00
#   timestep 0
# Time: 20241106 1200
# Fr range: 2.223 – 15.653
# Supercritical points: 92 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 1210
# Fr range: 2.225 – 17.746
# Supercritical points: 92 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 1220
# Fr range: 2.241 – 20.519
# Supercritical points: 92 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 1230
# Fr range: 2.300 – 42.564
# Supercritical points: 93 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 1240
# Fr range: 2.290 – 34.157
# Supercritical points: 94 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 1250
# Fr range: 2.274 – 58.340
# Supercritical points: 95 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_20:00:00
#   timestep 0
# Time: 20241106 1300
# Fr range: 2.179 – 18.054
# Supercritical points: 93 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 1310
# Fr range: 2.081 – 21.262
# Supercritical points: 95 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 1320
# Fr range: 2.100 – 22.231
# Supercritical points: 95 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 1330
# Fr range: 2.062 – 46.155
# Supercritical points: 92 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 1340
# Fr range: 2.047 – 25.334
# Supercritical points: 94 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 1350
# Fr range: 2.014 – 19.141
# Supercritical points: 96 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_21:00:00
#   timestep 0
# Time: 20241106 1400
# Fr range: 2.018 – 19.098
# Supercritical points: 95 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 1410
# Fr range: 1.951 – 36.134
# Supercritical points: 96 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 1420
# Fr range: 1.933 – 19.038
# Supercritical points: 95 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 1430
# Fr range: 1.897 – 22.056
# Supercritical points: 94 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 1440
# Fr range: 1.803 – 56.539
# Supercritical points: 95 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 1450
# Fr range: 1.805 – 20.431
# Supercritical points: 91 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_22:00:00
#   timestep 0
# Time: 20241106 1500
# Fr range: 1.766 – 15.499
# Supercritical points: 94 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 1510
# Fr range: 1.709 – 16.680
# Supercritical points: 95 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 1520
# Fr range: 1.711 – 8.316
# Supercritical points: 93 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 1530
# Fr range: 1.664 – 7.877
# Supercritical points: 95 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 1540
# Fr range: 1.657 – 90.555
# Supercritical points: 97 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 1550
# Fr range: 1.725 – 11.615
# Supercritical points: 96 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_23:00:00
#   timestep 0
# Time: 20241106 1600
# Fr range: 1.836 – 14.045
# Supercritical points: 96 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 1610
# Fr range: 1.899 – 28.453
# Supercritical points: 96 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 1620
# Fr range: 1.827 – 85.028
# Supercritical points: 96 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 1630
# Fr range: 1.810 – 18.968
# Supercritical points: 94 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 1640
# Fr range: 1.866 – 22.352
# Supercritical points: 95 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 1650
# Fr range: 1.854 – 24.035
# Supercritical points: 96 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_00:00:00
#   timestep 0
# Time: 20241106 1700
# Fr range: 1.838 – 23.364
# Supercritical points: 96 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 1710
# Fr range: 1.873 – 16.461
# Supercritical points: 97 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 1720
# Fr range: 1.893 – 40.368
# Supercritical points: 105 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 1730
# Fr range: 1.942 – 79.111
# Supercritical points: 115 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 1740
# Fr range: 1.999 – 20.809
# Supercritical points: 126 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 1750
# Fr range: 1.984 – 39.794
# Supercritical points: 129 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_01:00:00
#   timestep 0
# Time: 20241106 1800
# Fr range: 2.030 – 36.810
# Supercritical points: 130 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 1810
# Fr range: 1.990 – 102.282
# Supercritical points: 134 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 1820
# Fr range: 1.936 – 49.478
# Supercritical points: 135 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 1830
# Fr range: 1.569 – 38.784
# Supercritical points: 137 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 1840
# Fr range: 1.395 – 28.391
# Supercritical points: 134 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 1850
# Fr range: 1.200 – 41.644
# Supercritical points: 134 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_02:00:00
#   timestep 0
# Time: 20241106 1900
# Fr range: 1.600 – 32.931
# Supercritical points: 140 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 1910
# Fr range: 1.940 – 59.913
# Supercritical points: 143 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 1920
# Fr range: 1.794 – 19.287
# Supercritical points: 142 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 1930
# Fr range: 1.568 – 46.094
# Supercritical points: 146 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 1940
# Fr range: 2.141 – 20.710
# Supercritical points: 146 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 1950
# Fr range: 2.116 – 12.390
# Supercritical points: 143 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_03:00:00
#   timestep 0
# Time: 20241106 2000
# Fr range: 2.066 – 14.303
# Supercritical points: 148 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 2010
# Fr range: 1.950 – 9.750
# Supercritical points: 147 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 2020
# Fr range: 2.138 – 10.177
# Supercritical points: 147 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 2030
# Fr range: 1.754 – 12.271
# Supercritical points: 143 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 2040
# Fr range: 1.615 – 12.305
# Supercritical points: 142 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 2050
# Fr range: 2.013 – 20.180
# Supercritical points: 142 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_04:00:00
#   timestep 0
# Time: 20241106 2100
# Fr range: 2.063 – 11.105
# Supercritical points: 141 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 2110
# Fr range: 1.884 – 11.993
# Supercritical points: 142 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 2120
# Fr range: 1.441 – 11.952
# Supercritical points: 140 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 2130
# Fr range: 1.584 – 20.505
# Supercritical points: 141 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 2140
# Fr range: 1.487 – 12.015
# Supercritical points: 142 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 2150
# Fr range: 1.472 – 12.893
# Supercritical points: 143 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_05:00:00
#   timestep 0
# Time: 20241106 2200
# Fr range: 1.309 – 11.372
# Supercritical points: 144 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 2210
# Fr range: 1.147 – 10.855
# Supercritical points: 144 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 2220
# Fr range: 0.932 – 10.160
# Supercritical points: 143 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 2230
# Fr range: 0.201 – 11.341
# Supercritical points: 143 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 2240
# Fr range: 0.121 – 10.349
# Supercritical points: 138 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 2250
# Fr range: 0.203 – 12.317
# Supercritical points: 139 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_06:00:00
#   timestep 0
# Time: 20241106 2300
# Fr range: 0.320 – 10.687
# Supercritical points: 136 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241106 2310
# Fr range: 0.094 – 11.239
# Supercritical points: 139 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241106 2320
# Fr range: 0.630 – 10.654
# Supercritical points: 136 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241106 2330
# Fr range: 0.655 – 9.226
# Supercritical points: 135 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241106 2340
# Fr range: 0.500 – 9.890
# Supercritical points: 135 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241106 2350
# Fr range: 0.043 – 7.865
# Supercritical points: 132 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_07:00:00
#   timestep 0
# Time: 20241107 0000
# Fr range: 0.404 – 8.189
# Supercritical points: 134 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241107 0010
# Fr range: 0.316 – 7.536
# Supercritical points: 130 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241107 0020
# Fr range: 0.062 – 7.183
# Supercritical points: 137 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241107 0030
# Fr range: 0.059 – 10.267
# Supercritical points: 137 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241107 0040
# Fr range: 0.024 – 7.784
# Supercritical points: 138 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241107 0050
# Fr range: 0.047 – 7.384
# Supercritical points: 137 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_08:00:00
#   timestep 0
# Time: 20241107 0100
# Fr range: 0.037 – 7.486
# Supercritical points: 137 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241107 0110
# Fr range: 0.102 – 7.434
# Supercritical points: 135 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241107 0120
# Fr range: 0.214 – 7.398
# Supercritical points: 140 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241107 0130
# Fr range: 0.245 – 7.216
# Supercritical points: 140 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241107 0140
# Fr range: 0.268 – 7.437
# Supercritical points: 140 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241107 0150
# Fr range: 0.239 – 7.571
# Supercritical points: 139 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_09:00:00
#   timestep 0
# Time: 20241107 0200
# Fr range: 0.004 – 7.637
# Supercritical points: 138 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241107 0210
# Fr range: 0.056 – 7.611
# Supercritical points: 138 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241107 0220
# Fr range: 0.059 – 7.621
# Supercritical points: 137 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241107 0230
# Fr range: 0.006 – 7.491
# Supercritical points: 135 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241107 0240
# Fr range: 0.112 – 7.402
# Supercritical points: 135 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241107 0250
# Fr range: 0.002 – 7.329
# Supercritical points: 132 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_10:00:00
#   timestep 0
# Time: 20241107 0300
# Fr range: 0.028 – 7.286
# Supercritical points: 131 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241107 0310
# Fr range: 0.018 – 7.198
# Supercritical points: 131 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241107 0320
# Fr range: 0.089 – 7.130
# Supercritical points: 131 / 148
# Sub to Super transition: +1.47 km from center
# Super to Sub transition: not found
#   timestep 3
# Time: 20241107 0330
# Fr range: 0.002 – 7.031
# Supercritical points: 131 / 148
# Sub to Super transition: +1.40 km from center
# Super to Sub transition: not found
#   timestep 4
# Time: 20241107 0340
# Fr range: 0.099 – 6.918
# Supercritical points: 132 / 148
# Sub to Super transition: +1.83 km from center
# Super to Sub transition: not found
#   timestep 5
# Time: 20241107 0350
# Fr range: 0.101 – 6.677
# Supercritical points: 131 / 148
# Sub to Super transition: +1.98 km from center
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_11:00:00
#   timestep 0
# Time: 20241107 0400
# Fr range: 0.016 – 6.433
# Supercritical points: 129 / 148
# Sub to Super transition: +1.88 km from center
# Super to Sub transition: not found
#   timestep 1
# Time: 20241107 0410
# Fr range: 0.009 – 6.511
# Supercritical points: 130 / 148
# Sub to Super transition: +2.08 km from center
# Super to Sub transition: not found
#   timestep 2
# Time: 20241107 0420
# Fr range: 0.002 – 6.513
# Supercritical points: 131 / 148
# Sub to Super transition: +2.32 km from center
# Super to Sub transition: not found
#   timestep 3
# Time: 20241107 0430
# Fr range: 0.048 – 6.650
# Supercritical points: 131 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241107 0440
# Fr range: 0.078 – 8.767
# Supercritical points: 132 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241107 0450
# Fr range: 0.036 – 12.695
# Supercritical points: 132 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_12:00:00
#   timestep 0
# Time: 20241107 0500
# Fr range: 0.023 – 8.789
# Supercritical points: 131 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241107 0510
# Fr range: 0.015 – 6.735
# Supercritical points: 132 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241107 0520
# Fr range: 0.013 – 6.776
# Supercritical points: 132 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241107 0530
# Fr range: 0.079 – 6.742
# Supercritical points: 132 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# Time: 20241107 0540
# Fr range: 0.067 – 6.914
# Supercritical points: 134 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 5
# Time: 20241107 0550
# Fr range: 0.101 – 7.189
# Supercritical points: 137 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_13:00:00
#   timestep 0
# Time: 20241107 0600
# Fr range: 0.060 – 7.131
# Supercritical points: 136 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 1
# Time: 20241107 0610
# Fr range: 0.009 – 7.014
# Supercritical points: 136 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 2
# Time: 20241107 0620
# Fr range: 0.046 – 7.251
# Supercritical points: 136 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 3
# Time: 20241107 0630
# Fr range: 0.000 – 7.810
# Supercritical points: 138 / 148
# Sub to Super transition: not found
# Super to Sub transition: not found
#   timestep 4
# ...
#   timestep 5
# Time: 20241108 0650
# Fr range: 0.080 – 2.665
# Supercritical points: 117 / 148
# Sub to Super transition: -10.12 km from center
# Super to Sub transition: -15.51 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_14:00:00
#   timestep 0
# Time: 20241108 0700
# Fr range: 0.054 – 2.717
# Supercritical points: 118 / 148
# Sub to Super transition: -19.41 km from center
# Super to Sub transition: not found
#   timestep 1
# Time: 20241108 0710
# Fr range: 0.001 – 2.708
# Supercritical points: 118 / 148
# Sub to Super transition: -13.06 km from center
# Super to Sub transition: -14.68 km from center
#   timestep 2
# Time: 20241108 0720
# Fr range: 0.007 – 2.680
# Supercritical points: 112 / 148
# Sub to Super transition: -13.40 km from center
# Super to Sub transition: -14.43 km from center
#   timestep 3
# Time: 20241108 0730
# Fr range: 0.052 – 2.660
# Supercritical points: 112 / 148
# Sub to Super transition: -19.76 km from center
# Super to Sub transition: -62.23 km from center
#   timestep 4
# Time: 20241108 0740
# Fr range: 0.068 – 2.658
# Supercritical points: 114 / 148
# Sub to Super transition: -19.85 km from center
# Super to Sub transition: not found
#   timestep 5
# Time: 20241108 0750
# Fr range: 0.062 – 2.683
# Supercritical points: 112 / 148
# Sub to Super transition: -11.32 km from center
# Super to Sub transition: -14.23 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_15:00:00
#   timestep 0
# Time: 20241108 0800
# Fr range: 0.034 – 2.691
# Supercritical points: 113 / 148
# Sub to Super transition: -11.51 km from center
# Super to Sub transition: -14.10 km from center
#   timestep 1
# Time: 20241108 0810
# Fr range: 0.017 – 2.723
# Supercritical points: 109 / 148
# Sub to Super transition: -11.79 km from center
# Super to Sub transition: -13.34 km from center
#   timestep 2
# Time: 20241108 0820
# Fr range: 0.055 – 2.771
# Supercritical points: 107 / 148
# Sub to Super transition: -11.52 km from center
# Super to Sub transition: -12.60 km from center
#   timestep 3
# Time: 20241108 0830
# Fr range: 0.016 – 2.953
# Supercritical points: 108 / 148
# Sub to Super transition: -4.60 km from center
# Super to Sub transition: -7.86 km from center
#   timestep 4
# Time: 20241108 0840
# Fr range: 0.029 – 3.362
# Supercritical points: 104 / 148
# Sub to Super transition: -5.67 km from center
# Super to Sub transition: -7.64 km from center
#   timestep 5
# Time: 20241108 0850
# Fr range: 0.029 – 3.976
# Supercritical points: 101 / 148
# Sub to Super transition: -10.66 km from center
# Super to Sub transition: -12.15 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_16:00:00
#   timestep 0
# Time: 20241108 0900
# Fr range: 0.018 – 6.323
# Supercritical points: 102 / 148
# Sub to Super transition: -11.45 km from center
# Super to Sub transition: -11.97 km from center
#   timestep 1
# Time: 20241108 0910
# Fr range: 0.078 – 14.425
# Supercritical points: 100 / 148
# Sub to Super transition: -11.28 km from center
# Super to Sub transition: -12.01 km from center
#   timestep 2
# Time: 20241108 0920
# Fr range: 0.099 – 14.213
# Supercritical points: 97 / 148
# Sub to Super transition: -27.83 km from center
# Super to Sub transition: -29.44 km from center
#   timestep 3
# Time: 20241108 0930
# Fr range: 0.117 – 17.105
# Supercritical points: 89 / 148
# Sub to Super transition: -6.05 km from center
# Super to Sub transition: -6.42 km from center
#   timestep 4
# Time: 20241108 0940
# Fr range: 0.043 – 20.075
# Supercritical points: 87 / 148
# Sub to Super transition: -28.21 km from center
# Super to Sub transition: -29.61 km from center
#   timestep 5
# Time: 20241108 0950
# Fr range: 0.222 – 66.290
# Supercritical points: 78 / 148
# Sub to Super transition: -32.87 km from center
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_17:00:00
#   timestep 0
# Time: 20241108 1000
# Fr range: 0.375 – 5.575
# Supercritical points: 71 / 148
# Sub to Super transition: -28.80 km from center
# Super to Sub transition: -66.90 km from center
#   timestep 1
# Time: 20241108 1010
# Fr range: 0.362 – 10.068
# Supercritical points: 67 / 148
# Sub to Super transition: -29.17 km from center
# Super to Sub transition: -51.68 km from center
#   timestep 2
# Time: 20241108 1020
# Fr range: 0.360 – 6.856
# Supercritical points: 61 / 148
# Sub to Super transition: -29.43 km from center
# Super to Sub transition: -51.25 km from center
#   timestep 3
# Time: 20241108 1030
# Fr range: 0.353 – 6.046
# Supercritical points: 59 / 148
# Sub to Super transition: -29.90 km from center
# Super to Sub transition: -50.35 km from center
#   timestep 4
# Time: 20241108 1040
# Fr range: 0.330 – 7.934
# Supercritical points: 49 / 148
# Sub to Super transition: -31.36 km from center
# Super to Sub transition: -47.75 km from center
#   timestep 5
# Time: 20241108 1050
# Fr range: 0.301 – 10.159
# Supercritical points: 48 / 148
# Sub to Super transition: -34.26 km from center
# Super to Sub transition: -46.18 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_18:00:00
#   timestep 0
# Time: 20241108 1100
# Fr range: 0.249 – 5.787
# Supercritical points: 41 / 148
# Sub to Super transition: -37.75 km from center
# Super to Sub transition: -45.62 km from center
#   timestep 1
# Time: 20241108 1110
# Fr range: 0.206 – 4.921
# Supercritical points: 35 / 148
# Sub to Super transition: -40.15 km from center
# Super to Sub transition: -45.12 km from center
#   timestep 2
# Time: 20241108 1120
# Fr range: 0.165 – 3.629
# Supercritical points: 22 / 148
# Sub to Super transition: +11.80 km from center
# Super to Sub transition: -0.24 km from center
#   timestep 3
# Time: 20241108 1130
# Fr range: 0.095 – 3.204
# Supercritical points: 21 / 148
# Sub to Super transition: +10.81 km from center
# Super to Sub transition: +0.62 km from center
#   timestep 4
# Time: 20241108 1140
# Fr range: 0.006 – 5.299
# Supercritical points: 25 / 148
# Sub to Super transition: +9.95 km from center
# Super to Sub transition: -2.72 km from center
#   timestep 5
# Time: 20241108 1150
# Fr range: 0.004 – 4.679
# Supercritical points: 26 / 148
# Sub to Super transition: +9.95 km from center
# Super to Sub transition: -0.89 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_19:00:00
#   timestep 0
# Time: 20241108 1200
# Fr range: 0.003 – 15.304
# Supercritical points: 23 / 148
# Sub to Super transition: +8.97 km from center
# Super to Sub transition: +0.10 km from center
#   timestep 1
# Time: 20241108 1210
# Fr range: 0.001 – 5.473
# Supercritical points: 15 / 148
# Sub to Super transition: +5.95 km from center
# Super to Sub transition: +1.10 km from center
#   timestep 2
# Time: 20241108 1220
# Fr range: 0.016 – 1.826
# Supercritical points: 10 / 148
# Sub to Super transition: +3.32 km from center
# Super to Sub transition: +2.18 km from center
#   timestep 3
# Time: 20241108 1230
# Fr range: 0.007 – 1.951
# Supercritical points: 10 / 148
# Sub to Super transition: +15.41 km from center
# Super to Sub transition: +14.20 km from center
#   timestep 4
# Time: 20241108 1240
# Fr range: 0.028 – 3.351
# Supercritical points: 10 / 148
# Sub to Super transition: -18.53 km from center
# Super to Sub transition: -18.66 km from center
#   timestep 5
# Time: 20241108 1250
# Fr range: 0.009 – 2.246
# Supercritical points: 14 / 148
# Sub to Super transition: -15.40 km from center
# Super to Sub transition: -18.10 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_20:00:00
#   timestep 0
# Time: 20241108 1300
# Fr range: 0.023 – 2.655
# Supercritical points: 10 / 148
# Sub to Super transition: -14.51 km from center
# Super to Sub transition: -16.73 km from center
#   timestep 1
# Time: 20241108 1310
# Fr range: 0.004 – 4.422
# Supercritical points: 10 / 148
# Sub to Super transition: -10.74 km from center
# Super to Sub transition: -12.73 km from center
#   timestep 2
# Time: 20241108 1320
# Fr range: 0.022 – 3.209
# Supercritical points: 14 / 148
# Sub to Super transition: -8.73 km from center
# Super to Sub transition: -11.49 km from center
#   timestep 3
# Time: 20241108 1330
# Fr range: 0.083 – 19.496
# Supercritical points: 11 / 148
# Sub to Super transition: -7.23 km from center
# Super to Sub transition: -11.47 km from center
#   timestep 4
# Time: 20241108 1340
# Fr range: 0.083 – 2.691
# Supercritical points: 16 / 148
# Sub to Super transition: -4.70 km from center
# Super to Sub transition: -9.94 km from center
#   timestep 5
# Time: 20241108 1350
# Fr range: 0.005 – 11.583
# Supercritical points: 18 / 148
# Sub to Super transition: -2.84 km from center
# Super to Sub transition: -10.63 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_21:00:00
#   timestep 0
# Time: 20241108 1400
# Fr range: 0.003 – 3.066
# Supercritical points: 16 / 148
# Sub to Super transition: +0.76 km from center
# Super to Sub transition: -10.27 km from center
#   timestep 1
# Time: 20241108 1410
# Fr range: 0.039 – 2.779
# Supercritical points: 19 / 148
# Sub to Super transition: +3.44 km from center
# Super to Sub transition: +0.55 km from center
#   timestep 2
# Time: 20241108 1420
# Fr range: 0.021 – 2.430
# Supercritical points: 25 / 148
# Sub to Super transition: +4.91 km from center
# Super to Sub transition: -9.31 km from center
#   timestep 3
# Time: 20241108 1430
# Fr range: 0.011 – 1.878
# Supercritical points: 28 / 148
# Sub to Super transition: +6.45 km from center
# Super to Sub transition: +5.31 km from center
#   timestep 4
# Time: 20241108 1440
# Fr range: 0.004 – 3.218
# Supercritical points: 25 / 148
# Sub to Super transition: +7.86 km from center
# Super to Sub transition: +6.17 km from center
#   timestep 5
# Time: 20241108 1450
# Fr range: 0.026 – 4.141
# Supercritical points: 16 / 148
# Sub to Super transition: +5.30 km from center
# Super to Sub transition: -3.36 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_22:00:00
#   timestep 0
# Time: 20241108 1500
# Fr range: 0.062 – 12.211
# Supercritical points: 17 / 148
# Sub to Super transition: +7.68 km from center
# Super to Sub transition: -4.19 km from center
#   timestep 1
# Time: 20241108 1510
# Fr range: 0.128 – 3.592
# Supercritical points: 24 / 148
# Sub to Super transition: +10.05 km from center
# Super to Sub transition: -5.83 km from center
#   timestep 2
# Time: 20241108 1520
# Fr range: 0.072 – 4.907
# Supercritical points: 34 / 148
# Sub to Super transition: +9.73 km from center
# Super to Sub transition: -6.59 km from center
#   timestep 3
# Time: 20241108 1530
# Fr range: 0.018 – 10.110
# Supercritical points: 38 / 148
# Sub to Super transition: +9.56 km from center
# Super to Sub transition: +7.30 km from center
#   timestep 4
# Time: 20241108 1540
# Fr range: 0.003 – 5.217
# Supercritical points: 36 / 148
# Sub to Super transition: +9.37 km from center
# Super to Sub transition: +7.72 km from center
#   timestep 5
# Time: 20241108 1550
# Fr range: 0.038 – 3.022
# Supercritical points: 37 / 148
# Sub to Super transition: +9.24 km from center
# Super to Sub transition: +8.14 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_23:00:00
#   timestep 0
# Time: 20241108 1600
# Fr range: 0.013 – 4.005
# Supercritical points: 34 / 148
# Sub to Super transition: +9.12 km from center
# Super to Sub transition: +8.67 km from center
#   timestep 1
# Time: 20241108 1610
# Fr range: 0.207 – 9.554
# Supercritical points: 32 / 148
# Sub to Super transition: +7.87 km from center
# Super to Sub transition: -4.21 km from center
#   timestep 2
# Time: 20241108 1620
# Fr range: 0.452 – 3.976
# Supercritical points: 54 / 148
# Sub to Super transition: +10.01 km from center
# Super to Sub transition: +9.94 km from center
#   timestep 3
# Time: 20241108 1630
# Fr range: 0.462 – 12.201
# Supercritical points: 62 / 148
# Sub to Super transition: +8.81 km from center
# Super to Sub transition: -4.15 km from center
#   timestep 4
# Time: 20241108 1640
# Fr range: 0.472 – 11.176
# Supercritical points: 73 / 148
# Sub to Super transition: +13.64 km from center
# Super to Sub transition: +12.71 km from center
#   timestep 5
# Time: 20241108 1650
# Fr range: 0.482 – 21.402
# Supercritical points: 74 / 148
# Sub to Super transition: +9.71 km from center
# Super to Sub transition: -6.00 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-09_00:00:00
#   timestep 0
# Time: 20241108 1700
# Fr range: 0.486 – 9.325
# Supercritical points: 77 / 148
# Sub to Super transition: +10.77 km from center
# Super to Sub transition: -8.02 km from center
#   timestep 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [17], in <cell line: 55>()
#      80 print(f'  timestep {idt}')
#      82 # Read 3-D fields
# ---> 83 timeWRF = wrf.getvar(ncfile, 'Times',   idt)
#      84 z       = wrf.getvar(ncfile, 'z',       idt)
#      85 U       = wrf.getvar(ncfile, 'ua',      idt)   # zonal wind (destaggered)
#
# File /glade/u/apps/opt/conda/envs/npl-2022b/lib/python3.8/site-packages/wrf/routines.py:354, in getvar(wrfin, varname, timeidx, method, squeeze, cache, meta, **kwargs)
#     350     raise ValueError("'{}' is not a valid variable name".format(varname))
#     352 _check_kargs(actual_var, kwargs)
# --> 354 return _FUNC_MAP[actual_var](wrfin, timeidx, method, squeeze, cache,
#     355                              meta, _key, **kwargs)
#
# File /glade/u/apps/opt/conda/envs/npl-2022b/lib/python3.8/site-packages/wrf/g_times.py:58, in get_times(wrfin, timeidx, method, squeeze, cache, meta, _key)
#       6 def get_times(wrfin, timeidx=0, method="cat", squeeze=True, cache=None,
#       7               meta=True, _key=None):
#       8     """Return a sequence of time objects.
#       9
#      10     This function reads the 'Times' variable and creates a sequence of
#    (...)
#      56
#      57     """
# ---> 58     return extract_times(wrfin, timeidx, method, squeeze, cache,
#      59                          meta=meta, do_xtime=False)
#
# File /glade/u/apps/opt/conda/envs/npl-2022b/lib/python3.8/site-packages/wrf/util.py:2522, in extract_times(wrfin, timeidx, method, squeeze, cache, meta, do_xtime)
#    2519     outarr = time_arr
#    2521 if not multitime:
# -> 2522     return outarr[timeidx]
#    2524 return outarr
#
# File /glade/u/apps/opt/conda/envs/npl-2022b/lib/python3.8/site-packages/xarray/core/dataarray.py:772, in DataArray.__getitem__(self, key)
#     769     return self._getitem_coord(key)
#     770 else:
#     771     # xarray-style array indexing
# --> 772     return self.isel(indexers=self._item_key_to_dict(key))
#
# File /glade/u/apps/opt/conda/envs/npl-2022b/lib/python3.8/site-packages/xarray/core/dataarray.py:1291, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1286     return self._from_temp_dataset(ds)
#    1288 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1289 # lists, or zero or one-dimensional np.ndarray's
# -> 1291 variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1292 indexes, index_variables = isel_indexes(self.xindexes, indexers)
#    1294 coords = {}
#
# File /glade/u/apps/opt/conda/envs/npl-2022b/lib/python3.8/site-packages/xarray/core/variable.py:1226, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1223 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1225 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1226 return self[key]
#
# File /glade/u/apps/opt/conda/envs/npl-2022b/lib/python3.8/site-packages/xarray/core/variable.py:786, in Variable.__getitem__(self, key)
#     773 """Return a new Variable object whose contents are consistent with
#     774 getting the provided key from the underlying data.
#     775
#    (...)
#     783 array `x.values` directly.
#     784 """
#     785 dims, indexer, new_order = self._broadcast_indexes(key)
# --> 786 data = as_indexable(self._data)[indexer]
#     787 if new_order:
#     788     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File /glade/u/apps/opt/conda/envs/npl-2022b/lib/python3.8/site-packages/xarray/core/indexing.py:1264, in NumpyIndexingAdapter.__getitem__(self, key)
#    1262 def __getitem__(self, key):
#    1263     array, key = self._indexing_array_and_key(key)
# -> 1264     return array[key]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
