# %%
# cross sections at an angle through a fixed center point

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import wrf
import xarray
from netCDF4 import Dataset
from datetime import timedelta, date

import cartopy.crs as crs
from cartopy.feature import NaturalEarthFeature
from cartopy import crs
from cartopy.feature import NaturalEarthFeature, COLORS
from matplotlib.cm import get_cmap

# %%
# colormap definition with white in the middle
n=39
x = 0.5
lower = plt.cm.seismic_r(np.linspace(0, x, n))
white = plt.cm.seismic_r(np.ones(80-2*n)*x)
upper = plt.cm.seismic_r(np.linspace(1-x, 1, n))
colors = np.vstack((lower, white, upper))
from matplotlib.colors import LinearSegmentedColormap
tmap = LinearSegmentedColormap.from_list('map_white', colors)

# %%
########## angled cross section through a fixed center point #########

# ── WRF data location ──────────────────────────────────────────────────────────
baseFolder = '/glade/derecho/scratch/gduine/mountain_fire/1km/'

# Glob all domain-3 output files in chronological order
wrf_files = sorted(glob.glob(os.path.join(baseFolder, 'wrfout_d03_*')))
print(f'Found {len(wrf_files)} WRF files')

# ── Cross-section geometry ──────────────────────────────────────────────────────
center_lat       = 34.318    # center point latitude  (°N)
center_lon       = -118.968  # center point longitude (°W, negative)
angle_from_north = 50.0      # degrees clockwise from north
half_length_km   = 20.0      # half-length of the cross section (km)

# Compute start (SW) and end (NE) lat/lon
angle_rad  = np.radians(angle_from_north)
delta_lat  = half_length_km * np.cos(angle_rad) / 111.0
delta_lon  = half_length_km * np.sin(angle_rad) / (111.0 * np.cos(np.radians(center_lat)))

start_lat = center_lat - delta_lat
start_lon = center_lon - delta_lon
end_lat   = center_lat + delta_lat
end_lon   = center_lon + delta_lon

print(f'Cross section: center ({center_lat}°N, {center_lon}°W), angle {angle_from_north}° from N')
print(f'  SW end: ({start_lat:.4f}°N, {start_lon:.4f}°W)')
print(f'  NE end: ({end_lat:.4f}°N,  {end_lon:.4f}°W)')
print(f'  Along-section wind = U·sin({angle_from_north:.0f}°) + V·cos({angle_from_north:.0f}°)')
print(f'  Positive = toward NE end of section')

# ── Plot / axis settings ────────────────────────────────────────────────────────
g          = 9.81
Vs_levels  = np.arange(-24, 26,  2)   # along-section wind contour levels
W_levels   = np.arange(-5,  5.2, 0.2)
th_levels  = np.arange(260, 340, 1)

xlim1 = -half_length_km   # km from center, SW end
xlim2 =  half_length_km   # km from center, NE end
ylim1 = 0
ylim2 = 3000

# Froude search: only look south of this distance from center (km)
north_limit_km = 15.0

# ── One-time setup (runs on first file) ────────────────────────────────────────
ter        = None
xy         = None
ter_line   = None
dist_1d    = None
cross_start= None
cross_end  = None

# ── Main loop: files then timesteps ────────────────────────────────────────────
for fName in wrf_files:

    ncfile = Dataset(fName)
    print(f'\nOpened: {fName}')

    # First-file initialisation: terrain + cross-section path
    if ter is None:
        ter = wrf.getvar(ncfile, 'ter', -1)

        cross_start = wrf.CoordPair(lat=start_lat, lon=start_lon)
        cross_end   = wrf.CoordPair(lat=end_lat,   lon=end_lon)
        ter_line    = wrf.interpline(ter, wrfin=ncfile,
                                     start_point=cross_start, end_point=cross_end)

        latLocs = [start_lat, end_lat]
        lonLocs = [start_lon, end_lon]
        xy = wrf.ll_to_xy(ncfile, latLocs, lonLocs)

        nx_cross = len(ter_line)
        dist_1d  = np.linspace(xlim1, xlim2, nx_cross)   # km from center
        print(f'Cross-section has {nx_cross} grid points')

    # 6 timesteps per file (every 10 minutes within each hour)
    for idt in range(1):

        print(f'  timestep {idt}')

        # Read 3-D fields
        timeWRF = wrf.getvar(ncfile, 'Times',   idt)
        z       = wrf.getvar(ncfile, 'z',       idt)
        U       = wrf.getvar(ncfile, 'ua',      idt)   # zonal wind (destaggered)
        V       = wrf.getvar(ncfile, 'va',      idt)   # meridional wind (destaggered)
        W       = wrf.getvar(ncfile, 'wa',      idt)
        th      = wrf.getvar(ncfile, 'th',      idt)
        pblh    = wrf.getvar(ncfile, 'PBLH',    idt)
        qv      = wrf.getvar(ncfile, 'QVAPOR',  idt)
        thv     = th * (1.0 + 0.61 * qv)

        # Time string
        ts               = pd.to_datetime(wrf.to_np(timeWRF))
        tsPST            = ts - pd.DateOffset(hours=8)
        tWRFstr          = ts.strftime('%Y%m%d_%H%M')
        tWRF_strPST      = tsPST.strftime('%Y%m%d %H%M')
        tWRF_strPST_fName= tsPST.strftime('%Y%m%d_%H%M')

        # Cross-section interpolation along the angled path
        xy_line    = wrf.xy(V,   start_point=xy[:, 0], end_point=xy[:, 1])
        U_cross    = wrf.interp2dxy(U,   xy_line, meta=True)
        V_cross    = wrf.interp2dxy(V,   xy_line, meta=True)
        W_cross    = wrf.interp2dxy(W,   xy_line, meta=True)
        z_cross    = wrf.interp2dxy(z,   xy_line, meta=True)
        th_cross   = wrf.interp2dxy(th,  xy_line, meta=True)
        thv_cross  = wrf.interp2dxy(thv, xy_line, meta=True)
        pblh_cross = wrf.interpline(pblh, wrfin=ncfile,
                                    start_point=cross_start, end_point=cross_end)

        # Rotate wind to along-section component
        # Along-section (positive = toward NE end):  Vs =  U·sin(θ) + V·cos(θ)
        U_np      = wrf.to_np(U_cross)                                    # (nz, nx)
        V_np      = wrf.to_np(V_cross)
        Valong_np = U_np * np.sin(angle_rad) + V_np * np.cos(angle_rad)

        # 2-D distance array for contourf (same shape as V_cross)
        nz, nx = U_np.shape
        dist_2d = np.tile(dist_1d, (nz, 1))

        # Numpy arrays for Froude number calculation (use along-section wind)
        pblh_np = wrf.to_np(pblh_cross)
        thv_np  = wrf.to_np(thv_cross)
        z_np    = wrf.to_np(z_cross)

        if   nz == 54:  offset = 2
        elif nz == 80:  offset = 3
        elif nz == 106: offset = 4
        else:           offset = 2

        fr_profile = np.full(nx, np.nan)

        for ix in range(nx):
            z_col      = z_np[:, ix]
            thv_col    = thv_np[:, ix]
            Valong_col = Valong_np[:, ix]
            zi         = pblh_np[ix]
            if zi <= 0:
                zi = 1.0
            above = np.where(z_col > zi)[0]
            if len(above) == 0:
                continue
            ind_zi   = max(above[0] - 1, 0)
            mean_thv = np.nanmean(thv_col[:ind_zi + 1])
            ind_free = min(ind_zi + offset, nz - 1)
            thv_free = thv_col[ind_free]
            mean_Vs  = np.nanmean(Valong_col[:ind_zi + 1])
            g_prime  = g * (thv_free - mean_thv) / mean_thv
            if g_prime <= 0:
                continue
            fr_profile[ix] = np.abs(mean_Vs) / np.sqrt(g_prime * zi)

        # ── Froude transition detection (in distance space) ─────────────────────
        is_super = fr_profile > 1.0
        transition_dists = {'sub_to_super': None, 'super_to_sub': None}

        for ix in range(nx - 2, -1, -1):   # NE to SW
            if np.isnan(fr_profile[ix]) or np.isnan(fr_profile[ix + 1]):
                continue
            if dist_1d[ix] > north_limit_km:
                continue
            fr_a, fr_b     = fr_profile[ix], fr_profile[ix + 1]
            dist_a, dist_b = dist_1d[ix],    dist_1d[ix + 1]
            dist_cross = dist_a + (1.0 - fr_a) * (dist_b - dist_a) / (fr_b - fr_a)

            if is_super[ix] and not is_super[ix + 1]:
                if transition_dists['sub_to_super'] is None:
                    transition_dists['sub_to_super'] = dist_cross
            elif not is_super[ix] and is_super[ix + 1]:
                if transition_dists['sub_to_super'] is not None \
                        and transition_dists['super_to_sub'] is None:
                    transition_dists['super_to_sub'] = dist_cross

        # ── Plotting ────────────────────────────────────────────────────────────
        fig = plt.figure(figsize=(22, 7))
        xlabel_str = f'Distance along {angle_from_north:.0f}° cross section [km]'
        time_label = 'WRF 1 km ' + tWRF_strPST[:8] + ' ' + tWRF_strPST[9:13] + ' PST'

        # ── Left panel: along-section wind ─────────────────────────────────────
        ax_V = plt.subplot(1, 2, 1)
        Vs_contours = ax_V.contourf(dist_2d, wrf.to_np(z_cross), Valong_np,
                                    levels=Vs_levels, cmap=tmap, extend='both')
        th_contours = ax_V.contour(dist_2d, wrf.to_np(z_cross), wrf.to_np(th_cross),
                                   levels=th_levels, colors='k')
        ax_V.fill_between(dist_1d, np.zeros(nx_cross), wrf.to_np(ter_line),
                          facecolor='saddlebrown')
        plt.clabel(th_contours, inline=1, fontsize=20, levels=th_levels[::3], fmt='%1.0f')
        cbar_V = fig.colorbar(Vs_contours, ax=ax_V, extend='both',
                              orientation='horizontal', location='bottom',
                              shrink=0.7, pad=0.15, aspect=30)
        cbar_V.set_label('Along-section wind [m s$^{-1}$]', fontsize=16)
        cbar_V.ax.tick_params(labelsize=14)
        ax_V.scatter([0], [50], marker='^', color='yellow', edgecolor='black',
                     linewidth=2.0, s=500, zorder=8)
        ax_V.set_ylabel('Elevation [m]', fontsize=24)
        ax_V.set_xlabel(xlabel_str, fontsize=20)
        ax_V.set_title(f'Along-section wind (U·sin{angle_from_north:.0f}°+V·cos{angle_from_north:.0f}°) [m s$^{{-1}}$]',
                       fontsize=18)
        plt.xticks(fontsize=20)
        plt.yticks(fontsize=20)
        plt.text(xlim1 + 1, ylim2 - 200, time_label,
                 fontsize=20,
                 bbox=dict(facecolor='white', edgecolor='white', boxstyle='round,pad=0.3'),
                 zorder=10)
        if transition_dists['sub_to_super'] is not None:
            ax_V.axvline(x=transition_dists['sub_to_super'], color='cyan', linewidth=3.5,
                         linestyle='--', label='sub to super', zorder=9)
        if transition_dists['super_to_sub'] is not None:
            ax_V.axvline(x=transition_dists['super_to_sub'], color='orange', linewidth=3.5,
                         linestyle='--', label='super to sub', zorder=9)
        if any(transition_dists.values()):
            ax_V.legend(fontsize=16, loc='upper right')
        plt.ylim(ylim1, ylim2)
        plt.xlim(xlim1, xlim2)

        # ── Right panel: W-component ────────────────────────────────────────────
        ax_W = plt.subplot(1, 2, 2)
        W_contours = ax_W.contourf(dist_2d, wrf.to_np(z_cross), wrf.to_np(W_cross),
                                   levels=W_levels, cmap=tmap, extend='both')
        th_contours = ax_W.contour(dist_2d, wrf.to_np(z_cross), wrf.to_np(th_cross),
                                   levels=th_levels, colors='k')
        ax_W.fill_between(dist_1d, np.zeros(nx_cross), wrf.to_np(ter_line),
                          facecolor='saddlebrown')
        plt.clabel(th_contours, inline=1, fontsize=20, levels=th_levels[::3], fmt='%1.0f')
        cbar_W = fig.colorbar(W_contours, ax=ax_W, extend='both',
                              orientation='horizontal', location='bottom',
                              shrink=0.7, pad=0.15, aspect=30)
        cbar_W.set_label('W [m s$^{-1}$]', fontsize=16)
        cbar_W.ax.tick_params(labelsize=14)
        ax_W.scatter([0], [50], marker='^', color='yellow', edgecolor='black',
                     linewidth=2.0, s=500, zorder=8)
        ax_W.set_xlabel(xlabel_str, fontsize=20)
        ax_W.set_title('W-component [m s$^{-1}$]', fontsize=18)
        ax_W.set_yticklabels([])
        plt.xticks(fontsize=20)
        plt.text(xlim1 + 1, ylim2 - 200, time_label,
                 fontsize=20,
                 bbox=dict(facecolor='white', edgecolor='white', boxstyle='round,pad=0.3'),
                 zorder=10)
        if transition_dists['sub_to_super'] is not None:
            ax_W.axvline(x=transition_dists['sub_to_super'], color='cyan', linewidth=3.5,
                         linestyle='--', label='sub to super', zorder=9)
        if transition_dists['super_to_sub'] is not None:
            ax_W.axvline(x=transition_dists['super_to_sub'], color='orange', linewidth=3.5,
                         linestyle='--', label='super to sub', zorder=9)
        if any(transition_dists.values()):
            ax_W.legend(fontsize=16, loc='upper right')
        plt.ylim(ylim1, ylim2)
        plt.xlim(xlim1, xlim2)

        # ── Diagnostics ─────────────────────────────────────────────────────────
        print(f'Time: {tWRF_strPST}')
        print(f'Fr range: {np.nanmin(fr_profile):.3f} – {np.nanmax(fr_profile):.3f}')
        print(f'Supercritical points: {np.sum(is_super)} / {nx}')
        if transition_dists['sub_to_super'] is not None:
            print(f'Sub to Super transition: {transition_dists["sub_to_super"]:+.2f} km from center')
        else:
            print('Sub to Super transition: not found')
        if transition_dists['super_to_sub'] is not None:
            print(f'Super to Sub transition: {transition_dists["super_to_sub"]:+.2f} km from center')
        else:
            print('Super to Sub transition: not found')

        plt.subplots_adjust(wspace=0.15)

        save_fName = (f'MtnFire_wrf1km_Cross_ang{angle_from_north:.0f}N'
                      f'_Valong_Wcomp_theta_{tWRF_strPST_fName}_PST.jpg')
        fig.savefig(save_fName, bbox_inches='tight', dpi=100)
        fig.clf()
        plt.close()

        del U_cross, V_cross, W_cross, th_cross, pblh_cross, thv_cross
        del Vs_contours, W_contours, th_contours, cbar_V, cbar_W, ax_V, ax_W, fig
        del tWRFstr, tWRF_strPST_fName

    ncfile.close()
# Out:
# Found 79 WRF files
# Cross section: center (34.318°N, -118.968°W), angle 50.0° from N
#   SW end: (34.2022°N, -119.1351°W)
#   NE end: (34.4338°N,  -118.8009°W)
#   Along-section wind = U·sin(50°) + V·cos(50°)
#   Positive = toward NE end of section
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_18:00:00
# Cross-section has 42 grid points
#   timestep 0
# Time: 20241105 1000
# Fr range: 4.489 – 87.187
# Supercritical points: 36 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_19:00:00
#   timestep 0
# Time: 20241105 1100
# Fr range: 0.561 – 11.156
# Supercritical points: 6 / 42
# Sub to Super transition: +9.23 km from center
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_20:00:00
#   timestep 0
# Time: 20241105 1200
# Fr range: 0.602 – 6.036
# Supercritical points: 6 / 42
# Sub to Super transition: +8.92 km from center
# Super to Sub transition: -4.36 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_21:00:00
#   timestep 0
# Time: 20241105 1300
# Fr range: 0.532 – 6.957
# Supercritical points: 13 / 42
# Sub to Super transition: +9.45 km from center
# Super to Sub transition: -6.26 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_22:00:00
#   timestep 0
# Time: 20241105 1400
# Fr range: 0.515 – 3.163
# Supercritical points: 17 / 42
# Sub to Super transition: +14.13 km from center
# Super to Sub transition: +12.64 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-05_23:00:00
#   timestep 0
# Time: 20241105 1500
# Fr range: 0.318 – 4.941
# Supercritical points: 8 / 42
# Sub to Super transition: +11.95 km from center
# Super to Sub transition: +10.55 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_00:00:00
#   timestep 0
# Time: 20241105 1600
# Fr range: 0.195 – 5.244
# Supercritical points: 16 / 42
# Sub to Super transition: +12.64 km from center
# Super to Sub transition: +12.06 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_01:00:00
#   timestep 0
# Time: 20241105 1700
# Fr range: 0.293 – 1.512
# Supercritical points: 9 / 42
# Sub to Super transition: +9.16 km from center
# Super to Sub transition: +5.77 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_02:00:00
#   timestep 0
# Time: 20241105 1800
# Fr range: 0.000 – 1.180
# Supercritical points: 3 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_03:00:00
#   timestep 0
# Time: 20241105 1900
# Fr range: 0.006 – 0.905
# Supercritical points: 0 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_04:00:00
#   timestep 0
# Time: 20241105 2000
# Fr range: 0.028 – 1.206
# Supercritical points: 3 / 42
# Sub to Super transition: -7.55 km from center
# Super to Sub transition: -10.58 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_05:00:00
#   timestep 0
# Time: 20241105 2100
# Fr range: 0.001 – 1.284
# Supercritical points: 3 / 42
# Sub to Super transition: +14.31 km from center
# Super to Sub transition: +11.64 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_06:00:00
#   timestep 0
# Time: 20241105 2200
# Fr range: 0.009 – 1.399
# Supercritical points: 4 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_07:00:00
#   timestep 0
# Time: 20241105 2300
# Fr range: 0.009 – 0.653
# Supercritical points: 0 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_08:00:00
#   timestep 0
# Time: 20241106 0000
# Fr range: 0.010 – 1.163
# Supercritical points: 1 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_09:00:00
#   timestep 0
# Time: 20241106 0100
# Fr range: 0.005 – 1.578
# Supercritical points: 18 / 42
# Sub to Super transition: +0.57 km from center
# Super to Sub transition: -0.17 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_10:00:00
#   timestep 0
# Time: 20241106 0200
# Fr range: 0.669 – 2.207
# Supercritical points: 35 / 42
# Sub to Super transition: +9.94 km from center
# Super to Sub transition: +5.40 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_11:00:00
#   timestep 0
# Time: 20241106 0300
# Fr range: 0.592 – 4.252
# Supercritical points: 28 / 42
# Sub to Super transition: -3.10 km from center
# Super to Sub transition: -6.33 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_12:00:00
#   timestep 0
# Time: 20241106 0400
# Fr range: 0.406 – 6.458
# Supercritical points: 34 / 42
# Sub to Super transition: -19.97 km from center
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_13:00:00
#   timestep 0
# Time: 20241106 0500
# Fr range: 1.930 – 11.274
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_14:00:00
#   timestep 0
# Time: 20241106 0600
# Fr range: 2.383 – 12.100
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_15:00:00
#   timestep 0
# Time: 20241106 0700
# Fr range: 2.549 – 34.038
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_16:00:00
#   timestep 0
# Time: 20241106 0800
# Fr range: 2.384 – 38.040
# Supercritical points: 39 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_17:00:00
#   timestep 0
# Time: 20241106 0900
# Fr range: 2.054 – 12.933
# Supercritical points: 35 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_18:00:00
#   timestep 0
# Time: 20241106 1000
# Fr range: 2.714 – 38.442
# Supercritical points: 35 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_19:00:00
#   timestep 0
# Time: 20241106 1100
# Fr range: 2.334 – 26.166
# Supercritical points: 38 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_20:00:00
#   timestep 0
# Time: 20241106 1200
# Fr range: 2.119 – 17.586
# Supercritical points: 38 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_21:00:00
#   timestep 0
# Time: 20241106 1300
# Fr range: 2.016 – 21.230
# Supercritical points: 38 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_22:00:00
#   timestep 0
# Time: 20241106 1400
# Fr range: 1.984 – 21.771
# Supercritical points: 37 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-06_23:00:00
#   timestep 0
# Time: 20241106 1500
# Fr range: 1.988 – 21.742
# Supercritical points: 40 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_00:00:00
#   timestep 0
# Time: 20241106 1600
# Fr range: 1.863 – 12.766
# Supercritical points: 40 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_01:00:00
#   timestep 0
# Time: 20241106 1700
# Fr range: 2.091 – 42.966
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_02:00:00
#   timestep 0
# Time: 20241106 1800
# Fr range: 2.663 – 35.876
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_03:00:00
#   timestep 0
# Time: 20241106 1900
# Fr range: 2.175 – 10.432
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_04:00:00
#   timestep 0
# Time: 20241106 2000
# Fr range: 2.218 – 11.781
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_05:00:00
#   timestep 0
# Time: 20241106 2100
# Fr range: 2.144 – 11.756
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_06:00:00
#   timestep 0
# Time: 20241106 2200
# Fr range: 2.578 – 9.485
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_07:00:00
#   timestep 0
# Time: 20241106 2300
# Fr range: 2.494 – 7.865
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_08:00:00
#   timestep 0
# Time: 20241107 0000
# Fr range: 2.271 – 7.800
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_09:00:00
#   timestep 0
# Time: 20241107 0100
# Fr range: 1.894 – 7.599
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_10:00:00
#   timestep 0
# Time: 20241107 0200
# Fr range: 1.048 – 6.537
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_11:00:00
#   timestep 0
# Time: 20241107 0300
# Fr range: 0.740 – 6.073
# Supercritical points: 40 / 42
# Sub to Super transition: +1.41 km from center
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_12:00:00
#   timestep 0
# Time: 20241107 0400
# Fr range: 1.602 – 6.133
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_13:00:00
#   timestep 0
# Time: 20241107 0500
# Fr range: 1.620 – 6.710
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_14:00:00
#   timestep 0
# Time: 20241107 0600
# Fr range: 2.259 – 8.566
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_15:00:00
#   timestep 0
# Time: 20241107 0700
# Fr range: 1.927 – 9.320
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_16:00:00
#   timestep 0
# Time: 20241107 0800
# Fr range: 2.039 – 46.200
# Supercritical points: 37 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_17:00:00
#   timestep 0
# Time: 20241107 0900
# Fr range: 1.951 – 35.789
# Supercritical points: 34 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_18:00:00
#   timestep 0
# Time: 20241107 1000
# Fr range: 1.765 – 11.950
# Supercritical points: 34 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_19:00:00
#   timestep 0
# Time: 20241107 1100
# Fr range: 1.634 – 10.014
# Supercritical points: 36 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_20:00:00
#   timestep 0
# Time: 20241107 1200
# Fr range: 1.528 – 10.523
# Supercritical points: 36 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_21:00:00
#   timestep 0
# Time: 20241107 1300
# Fr range: 1.246 – 11.072
# Supercritical points: 38 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_22:00:00
#   timestep 0
# Time: 20241107 1400
# Fr range: 1.124 – 58.083
# Supercritical points: 40 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-07_23:00:00
#   timestep 0
# Time: 20241107 1500
# Fr range: 1.146 – 17.665
# Supercritical points: 41 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_00:00:00
#   timestep 0
# Time: 20241107 1600
# Fr range: 1.337 – 8.841
# Supercritical points: 41 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_01:00:00
#   timestep 0
# Time: 20241107 1700
# Fr range: 1.038 – 4.595
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_02:00:00
#   timestep 0
# Time: 20241107 1800
# Fr range: 1.453 – 4.645
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_03:00:00
#   timestep 0
# Time: 20241107 1900
# Fr range: 1.609 – 4.616
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_04:00:00
#   timestep 0
# Time: 20241107 2000
# Fr range: 1.570 – 4.578
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_05:00:00
#   timestep 0
# Time: 20241107 2100
# Fr range: 1.346 – 4.449
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_06:00:00
#   timestep 0
# Time: 20241107 2200
# Fr range: 1.185 – 4.185
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_07:00:00
#   timestep 0
# Time: 20241107 2300
# Fr range: 1.282 – 3.936
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_08:00:00
#   timestep 0
# Time: 20241108 0000
# Fr range: 1.033 – 3.773
# Supercritical points: 42 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_09:00:00
#   timestep 0
# Time: 20241108 0100
# Fr range: 0.832 – 3.493
# Supercritical points: 40 / 42
# Sub to Super transition: -9.22 km from center
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_10:00:00
#   timestep 0
# Time: 20241108 0200
# Fr range: 0.698 – 3.200
# Supercritical points: 34 / 42
# Sub to Super transition: -5.96 km from center
# Super to Sub transition: -6.65 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_11:00:00
#   timestep 0
# Time: 20241108 0300
# Fr range: 0.645 – 3.060
# Supercritical points: 31 / 42
# Sub to Super transition: -9.95 km from center
# Super to Sub transition: -12.04 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_12:00:00
#   timestep 0
# Time: 20241108 0400
# Fr range: 0.589 – 2.574
# Supercritical points: 33 / 42
# Sub to Super transition: -10.12 km from center
# Super to Sub transition: -13.32 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_13:00:00
#   timestep 0
# Time: 20241108 0500
# Fr range: 0.867 – 2.534
# Supercritical points: 33 / 42
# Sub to Super transition: -10.41 km from center
# Super to Sub transition: -12.56 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_14:00:00
#   timestep 0
# Time: 20241108 0600
# Fr range: 0.895 – 2.686
# Supercritical points: 36 / 42
# Sub to Super transition: -10.04 km from center
# Super to Sub transition: -14.35 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_15:00:00
#   timestep 0
# Time: 20241108 0700
# Fr range: 0.662 – 2.622
# Supercritical points: 35 / 42
# Sub to Super transition: -10.90 km from center
# Super to Sub transition: -11.83 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_16:00:00
#   timestep 0
# Time: 20241108 0800
# Fr range: 0.539 – 3.793
# Supercritical points: 27 / 42
# Sub to Super transition: -11.35 km from center
# Super to Sub transition: -12.28 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_17:00:00
#   timestep 0
# Time: 20241108 0900
# Fr range: 0.411 – 16.545
# Supercritical points: 21 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_18:00:00
#   timestep 0
# Time: 20241108 1000
# Fr range: 0.265 – 3.981
# Supercritical points: 20 / 42
# Sub to Super transition: not found
# Super to Sub transition: not found
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_19:00:00
#   timestep 0
# Time: 20241108 1100
# Fr range: 0.000 – 1.491
# Supercritical points: 14 / 42
# Sub to Super transition: +9.20 km from center
# Super to Sub transition: +0.19 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_20:00:00
#   timestep 0
# Time: 20241108 1200
# Fr range: 0.005 – 1.715
# Supercritical points: 5 / 42
# Sub to Super transition: -14.06 km from center
# Super to Sub transition: -17.56 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_21:00:00
#   timestep 0
# Time: 20241108 1300
# Fr range: 0.020 – 1.220
# Supercritical points: 8 / 42
# Sub to Super transition: +0.79 km from center
# Super to Sub transition: -1.38 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_22:00:00
#   timestep 0
# Time: 20241108 1400
# Fr range: 0.230 – 5.843
# Supercritical points: 11 / 42
# Sub to Super transition: +7.60 km from center
# Super to Sub transition: -4.33 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-08_23:00:00
#   timestep 0
# Time: 20241108 1500
# Fr range: 0.495 – 2.485
# Supercritical points: 15 / 42
# Sub to Super transition: +9.34 km from center
# Super to Sub transition: +8.96 km from center
#
# Opened: /glade/derecho/scratch/gduine/mountain_fire/1km/wrfout_d03_2024-11-09_00:00:00
#   timestep 0
# Time: 20241108 1600
# Fr range: 0.503 – 35.541
# Supercritical points: 23 / 42
# Sub to Super transition: +11.02 km from center
# Super to Sub transition: -8.22 km from center
